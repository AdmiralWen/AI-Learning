# %%
import os
import openai
from dotenv import load_dotenv
from azure.identity import AzureCliCredential

# %%
# Load env variables:
load_dotenv('.env')
OPENAI_API_ENDPOINT=os.getenv("OPENAI_API_ENDPOINT")
#OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")
AZURE_OPENAI_DEPLOYMENT_NAME=os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME_52")
OPENAI_API_VERSION=os.getenv("OPENAI_API_VERSION")
RESOURCE_TENANT_ID=os.getenv("RESOURCE_TENANT_ID")

# %%
# Make sure to have the azure cli installed.
# In terminal type `az login` to login, then login on your browser popup, then select an environment in the terminal (usually 1):
credential = AzureCliCredential(tenant_id=RESOURCE_TENANT_ID)
token = credential.get_token("https://cognitiveservices.azure.com/.default")

# %%
# Create OpenAI client:
client = openai.AzureOpenAI(
    api_key = token.token,
    api_version = OPENAI_API_VERSION,
    azure_endpoint = OPENAI_API_ENDPOINT
)

# %%
# Test chat completion:
response = client.chat.completions.create(
    #model=AZURE_OPENAI_DEPLOYMENT_NAME,
    model="gpt-5.2",
    messages=[
        {"role": "system", "content": "Assistant is a large language model trained by OpenAI."},
        {"role": "user", "content": "Explain what MCP servers are in simple terms."}
    ]
)
print(response.choices[0].message.content)
# Out:
# MCP servers are programs that let an AI assistant securely use tools and data from other apps.
#
# In simple terms:
#
# - **MCP (Model Context Protocol)** is a standard “plug” that connects an AI model to external things.
# - An **MCP server** is the tool-provider side of that connection. It exposes capabilities like:
#   - reading/writing files
#   - querying a database
#   - calling internal APIs
#   - searching documents
#   - running approved commands
# - The AI talks to the MCP server using a consistent protocol, so it doesn’t need a custom integration for every tool.
#
# Why they matter:
#
# - **Standardized**: one common way to connect many tools.
# - **Safer**: access can be scoped (only certain tools/data allowed).
# - **More useful**: the AI can fetch real information and take actions, not just generate text.
#
# Analogy: the AI is a person, and MCP servers are the “service desk” that can access specific systems on the person’s behalf, with rules about what’s allowed.
